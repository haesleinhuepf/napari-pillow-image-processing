# %%
from skimage.io import imread, imshow

# %%
image = imread("blobs.tif")

# %%
image3d = imread("Haase_MRT_tfl3d1.tif")

# %%
from napari_pillow_image_processing import gaussian_blur

imshow(gaussian_blur(image, 5))
# Out:
# No viewer provided, cannot read current time point.
# Computing result took 0.002001047134399414

# %%
from napari_pillow_image_processing import gaussian_blur

imshow(gaussian_blur(image3d, 3)[60])
# Out:
# No viewer provided, cannot read current time point.
# Computing result took 0.18304204940795898

# %%
from napari_pillow_image_processing import box_blur

imshow(box_blur(image3d, 5)[60])

# %%
from napari_pillow_image_processing import unsharp_mask

imshow(unsharp_mask(image3d, threshold = 0.5)[60])

# %%
from napari_pillow_image_processing import median_filter
        
imshow(median_filter(image3d)[60])

# %%
from napari_pillow_image_processing import minimum_filter
        
imshow(minimum_filter(image3d, 2)[60])

# %%
from napari_pillow_image_processing import maximum_filter
        
imshow(maximum_filter(image3d, 2)[60])

# %%
from napari_pillow_image_processing import mode_filter

imshow(mode_filter(image3d, 2)[60])

# %%
from napari_pillow_image_processing import auto_contrast
        
imshow(auto_contrast(image3d, 10)[60])

# %%
from napari_pillow_image_processing import equalize_histogram_bins

imshow(equalize_histogram_bins(image3d)[60])

# %%
from napari_pillow_image_processing import enhance_contrast

imshow(enhance_contrast(image3d, 3)[60])

# %%
from napari_pillow_image_processing import enhance_brightness

imshow(enhance_brightness(image3d, 0.5)[60])

# %%
from napari_pillow_image_processing import enhance_sharpness
        
imshow(enhance_sharpness(image3d, 5)[60])
